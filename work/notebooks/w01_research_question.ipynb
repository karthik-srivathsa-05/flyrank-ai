# %% [markdown]
# <a href="https://colab.research.google.com/github/karthik-srivathsa-05/flyrank-ai/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/karthik-srivathsa-05/flyrank-ai/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# **Lane: Content Refresh Prioritization**
#
# I want to investigate how search, content, and performance signals can be used to prioritize which pages should be reviewed or refreshed first. I chose this lane because the starter dataset contains multiple signals about page performance, content characteristics, and search visibility, and the first notebook showed that a learned model can rank potentially declining pages substantially better than a simple hand-written rule. My goal is to determine which signals are useful for prioritization and whether a data-driven ranking can support more efficient content-review decisions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# The decision is **which pages should be reviewed or refreshed first**. A content or SEO team would act on the ranked output by allocating review time to the pages with the highest priority. A wrong recommendation can waste limited editorial time on a page that does not need attention, while failing to prioritize a genuinely declining page can delay an appropriate content or optimization response. The work is therefore useful if it can rank pages more effectively than a simple rule, while keeping the evaluation tied to observed outcomes rather than claiming to predict Google's ranking system.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# The starter dataset contains **30,000 anonymized rows across 32 clients and 3 content types**. The first pipeline run also showed a Precision@50 of **0.240 for the hand-written baseline versus 0.740 for the random-forest model** on the client-holdout evaluation. These results indicate that the dataset contains measurable signal for prioritizing pages for review and make content-refresh prioritization a useful lane to investigate further.

# %%
import os
import pandas as pd

# Find the repository root
if not os.path.exists("data/raw/content_refresh_anonymized.csv"):
    if os.path.exists("flyrank-ai/data/raw/content_refresh_anonymized.csv"):
        os.chdir("flyrank-ai")
    elif os.path.exists("flyrank-ml-internship-starter/data/raw/content_refresh_anonymized.csv"):
        os.chdir("flyrank-ml-internship-starter")

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Clients:", df["client_id"].nunique())
print("Content types:", df["content_type"].nunique())
# Out:
# Rows: 30000
# Clients: 32
# Content types: 3

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# I can claim that patterns and model performance are **observed and measured within the available dataset and evaluation setup**. Results can be used as **directional evidence** about which signals may help prioritize pages for review, and the resulting rankings can serve as **decision-support** for content-review work.
#
# I cannot claim that the analysis proves causal relationships, that a particular signal causes search performance to change, or that the model predicts Google's ranking algorithm. The results are specific to the data, features, labels, and validation setup used in the study.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
